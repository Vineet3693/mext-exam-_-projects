# %% [markdown]
# <a href="https://colab.research.google.com/github/Vineet3693/mext-exam-_-projects/blob/main/Handwritten_Digit_Generation_Web_App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Set Up Development Environment

# %%
# For training (Google Colab)
# !pip install torch torchvision streamlit

# For web app
# !pip install streamlit torch torchvision pillow numpy
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Collecting streamlit
#   Downloading streamlit-1.46.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.43.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 36.5 MB/s eta 0:00:00
# Downloading streamlit-1.46.0-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 45.3 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 27.3 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: watchdog, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, pydeck, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, streamlit
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pydeck-0.9.1 streamlit-1.46.0 watchdog-6.0.0
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (1.46.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.14.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.43.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %% [markdown]
# Build and Train the Generative Model

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))  # Normalize to [-1, 1]
])

train_dataset = torchvision.datasets.MNIST(
    root='./data', train=True, download=True, transform=transform
)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)

# Define Generator (GAN approach)
class Generator(nn.Module):
    def __init__(self, latent_dim=100, num_classes=10):
        super(Generator, self).__init__()
        self.latent_dim = latent_dim
        self.num_classes = num_classes

        # Embedding for class labels
        self.label_embedding = nn.Embedding(num_classes, num_classes)

        self.model = nn.Sequential(
            nn.Linear(latent_dim + num_classes, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, 28*28),
            nn.Tanh()
        )

    def forward(self, noise, labels):
        # Embed labels
        label_embedding = self.label_embedding(labels)
        # Concatenate noise and label embedding
        input_tensor = torch.cat([noise, label_embedding], dim=1)
        img = self.model(input_tensor)
        img = img.view(img.size(0), 1, 28, 28)
        return img

# Define Discriminator
class Discriminator(nn.Module):
    def __init__(self, num_classes=10):
        super(Discriminator, self).__init__()
        self.num_classes = num_classes

        # Embedding for class labels
        self.label_embedding = nn.Embedding(num_classes, num_classes)

        self.model = nn.Sequential(
            nn.Linear(28*28 + num_classes, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, img, labels):
        # Flatten image
        img_flat = img.view(img.size(0), -1)
        # Embed labels
        label_embedding = self.label_embedding(labels)
        # Concatenate image and label embedding
        input_tensor = torch.cat([img_flat, label_embedding], dim=1)
        validity = self.model(input_tensor)
        return validity

# Initialize models
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Loss function and optimizers
adversarial_loss = nn.BCELoss()
optimizer_G = optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Training loop
num_epochs = 50
latent_dim = 100

for epoch in range(num_epochs):
    for i, (imgs, labels) in enumerate(train_loader):
        batch_size = imgs.shape[0]

        # Ground truth labels
        real_labels = torch.ones(batch_size, 1).to(device)
        fake_labels = torch.zeros(batch_size, 1).to(device)

        # Move to device
        real_imgs = imgs.to(device)
        labels = labels.to(device)

        # Train Discriminator
        optimizer_D.zero_grad()

        # Real images
        real_validity = discriminator(real_imgs, labels)
        d_real_loss = adversarial_loss(real_validity, real_labels)

        # Fake images
        noise = torch.randn(batch_size, latent_dim).to(device)
        fake_labels_gen = torch.randint(0, 10, (batch_size,)).to(device)
        fake_imgs = generator(noise, fake_labels_gen)
        fake_validity = discriminator(fake_imgs.detach(), fake_labels_gen)
        d_fake_loss = adversarial_loss(fake_validity, fake_labels)

        d_loss = (d_real_loss + d_fake_loss) / 2
        d_loss.backward()
        optimizer_D.step()

        # Train Generator
        optimizer_G.zero_grad()

        fake_validity = discriminator(fake_imgs, fake_labels_gen)
        g_loss = adversarial_loss(fake_validity, real_labels)

        g_loss.backward()
        optimizer_G.step()

        if i % 100 == 0:
            print(f"Epoch {epoch}/{num_epochs}, Batch {i}, D Loss: {d_loss.item():.4f}, G Loss: {g_loss.item():.4f}")

# Save the trained generator
torch.save(generator.state_dict(), 'generator.pth')
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.1MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 483kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.48MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 4.99MB/s]
# Epoch 0/50, Batch 0, D Loss: 0.6886, G Loss: 0.7271
# Epoch 0/50, Batch 100, D Loss: 0.7662, G Loss: 0.7019
# Epoch 0/50, Batch 200, D Loss: 0.5505, G Loss: 1.1444
# Epoch 0/50, Batch 300, D Loss: 0.4785, G Loss: 1.2735
# Epoch 0/50, Batch 400, D Loss: 0.4033, G Loss: 2.2358
# Epoch 1/50, Batch 0, D Loss: 0.3522, G Loss: 1.4101
# Epoch 1/50, Batch 100, D Loss: 0.6601, G Loss: 3.6967
# Epoch 1/50, Batch 200, D Loss: 0.1482, G Loss: 3.1093
# Epoch 1/50, Batch 300, D Loss: 0.3639, G Loss: 2.8356
# Epoch 1/50, Batch 400, D Loss: 0.5522, G Loss: 5.4513
# Epoch 2/50, Batch 0, D Loss: 0.2286, G Loss: 5.6320
# Epoch 2/50, Batch 100, D Loss: 0.1828, G Loss: 2.7891
# Epoch 2/50, Batch 200, D Loss: 0.8369, G Loss: 2.8640
# Epoch 2/50, Batch 300, D Loss: 0.2811, G Loss: 2.0585
# Epoch 2/50, Batch 400, D Loss: 0.1643, G Loss: 3.5201
# Epoch 3/50, Batch 0, D Loss: 0.1409, G Loss: 3.0687
# Epoch 3/50, Batch 100, D Loss: 0.2791, G Loss: 2.4494
# Epoch 3/50, Batch 200, D Loss: 0.1450, G Loss: 3.4182
# Epoch 3/50, Batch 300, D Loss: 0.1870, G Loss: 2.5740
# Epoch 3/50, Batch 400, D Loss: 0.5801, G Loss: 0.8491
# Epoch 4/50, Batch 0, D Loss: 0.1872, G Loss: 4.3449
# Epoch 4/50, Batch 100, D Loss: 0.1236, G Loss: 4.7737
# Epoch 4/50, Batch 200, D Loss: 0.2927, G Loss: 5.2865
# Epoch 4/50, Batch 300, D Loss: 0.1836, G Loss: 3.9527
# Epoch 4/50, Batch 400, D Loss: 0.1300, G Loss: 4.0027
# Epoch 5/50, Batch 0, D Loss: 0.1424, G Loss: 2.9272
# Epoch 5/50, Batch 100, D Loss: 0.1105, G Loss: 3.7452
# Epoch 5/50, Batch 200, D Loss: 0.2810, G Loss: 2.5405
# Epoch 5/50, Batch 300, D Loss: 0.2580, G Loss: 3.5062
# Epoch 5/50, Batch 400, D Loss: 0.2106, G Loss: 4.6220
# Epoch 6/50, Batch 0, D Loss: 0.1101, G Loss: 4.7024
# Epoch 6/50, Batch 100, D Loss: 0.1688, G Loss: 2.9080
# Epoch 6/50, Batch 200, D Loss: 0.1075, G Loss: 4.3978
# Epoch 6/50, Batch 300, D Loss: 0.6302, G Loss: 5.9987
# Epoch 6/50, Batch 400, D Loss: 0.0331, G Loss: 4.2649
# Epoch 7/50, Batch 0, D Loss: 0.6256, G Loss: 9.7181
# Epoch 7/50, Batch 100, D Loss: 0.4830, G Loss: 7.3759
# Epoch 7/50, Batch 200, D Loss: 0.3245, G Loss: 4.5234
# Epoch 7/50, Batch 300, D Loss: 0.1493, G Loss: 5.5233
# Epoch 7/50, Batch 400, D Loss: 0.0655, G Loss: 4.2233
# Epoch 8/50, Batch 0, D Loss: 0.0912, G Loss: 4.0242
# Epoch 8/50, Batch 100, D Loss: 0.1746, G Loss: 12.0451
# Epoch 8/50, Batch 200, D Loss: 0.0458, G Loss: 6.7083
# Epoch 8/50, Batch 300, D Loss: 0.0669, G Loss: 4.2489
# Epoch 8/50, Batch 400, D Loss: 0.1873, G Loss: 4.9774
# Epoch 9/50, Batch 0, D Loss: 0.1289, G Loss: 3.5780
# Epoch 9/50, Batch 100, D Loss: 0.0519, G Loss: 5.6888
# Epoch 9/50, Batch 200, D Loss: 0.0035, G Loss: 6.5783
# Epoch 9/50, Batch 300, D Loss: 0.0017, G Loss: 7.5723
# Epoch 9/50, Batch 400, D Loss: 0.0725, G Loss: 7.1120
# Epoch 10/50, Batch 0, D Loss: 0.0249, G Loss: 4.9603
# Epoch 10/50, Batch 100, D Loss: 1.1431, G Loss: 4.7327
# Epoch 10/50, Batch 200, D Loss: 0.0485, G Loss: 5.2510
# Epoch 10/50, Batch 300, D Loss: 0.0063, G Loss: 7.3401
# Epoch 10/50, Batch 400, D Loss: 0.0465, G Loss: 3.9309
# Epoch 11/50, Batch 0, D Loss: 0.0103, G Loss: 5.6839
# Epoch 11/50, Batch 100, D Loss: 0.0017, G Loss: 7.0841
# Epoch 11/50, Batch 200, D Loss: 0.0031, G Loss: 6.0892
# Epoch 11/50, Batch 300, D Loss: 0.0085, G Loss: 5.4765
# Epoch 11/50, Batch 400, D Loss: 0.0243, G Loss: 7.1056
# Epoch 12/50, Batch 0, D Loss: 0.0101, G Loss: 5.5345
# Epoch 12/50, Batch 100, D Loss: 0.0243, G Loss: 5.9426
# Epoch 12/50, Batch 200, D Loss: 0.0191, G Loss: 6.2548
# Epoch 12/50, Batch 300, D Loss: 0.0046, G Loss: 6.6104
# Epoch 12/50, Batch 400, D Loss: 0.0019, G Loss: 7.8819
# Epoch 13/50, Batch 0, D Loss: 0.0193, G Loss: 7.1329
# Epoch 13/50, Batch 100, D Loss: 0.0029, G Loss: 6.4889
# Epoch 13/50, Batch 200, D Loss: 0.0041, G Loss: 6.0254
# Epoch 13/50, Batch 300, D Loss: 0.0013, G Loss: 6.9401
# Epoch 13/50, Batch 400, D Loss: 0.0003, G Loss: 8.2186
# Epoch 14/50, Batch 0, D Loss: 0.0007, G Loss: 8.7797
# Epoch 14/50, Batch 100, D Loss: 0.0002, G Loss: 9.2376
# Epoch 14/50, Batch 200, D Loss: 0.0041, G Loss: 7.2389
# Epoch 14/50, Batch 300, D Loss: 0.0019, G Loss: 8.9533
# Epoch 14/50, Batch 400, D Loss: 0.0002, G Loss: 9.6975
# Epoch 15/50, Batch 0, D Loss: 0.0001, G Loss: 10.1877
# Epoch 15/50, Batch 100, D Loss: 0.0001, G Loss: 10.2173
# Epoch 15/50, Batch 200, D Loss: 0.0001, G Loss: 10.8530
# Epoch 15/50, Batch 300, D Loss: 0.0000, G Loss: 10.6328
# Epoch 15/50, Batch 400, D Loss: 0.0002, G Loss: 10.5432
# Epoch 16/50, Batch 0, D Loss: 0.0000, G Loss: 11.0076
# Epoch 16/50, Batch 100, D Loss: 0.0001, G Loss: 11.1031
# Epoch 16/50, Batch 200, D Loss: 0.0000, G Loss: 11.2909
# Epoch 16/50, Batch 300, D Loss: 0.0000, G Loss: 11.6412
# Epoch 16/50, Batch 400, D Loss: 0.0000, G Loss: 11.5956
# Epoch 17/50, Batch 0, D Loss: 0.0000, G Loss: 11.8744
# Epoch 17/50, Batch 100, D Loss: 0.0000, G Loss: 11.6028
# Epoch 17/50, Batch 200, D Loss: 0.0000, G Loss: 11.3706
# Epoch 17/50, Batch 300, D Loss: 0.0124, G Loss: 7.3750
# Epoch 17/50, Batch 400, D Loss: 0.0113, G Loss: 7.0258
# Epoch 18/50, Batch 0, D Loss: 0.0018, G Loss: 6.3865
# Epoch 18/50, Batch 100, D Loss: 0.0002, G Loss: 8.4993
# Epoch 18/50, Batch 200, D Loss: 0.0001, G Loss: 8.7236
# Epoch 18/50, Batch 300, D Loss: 0.0001, G Loss: 8.5878
# Epoch 18/50, Batch 400, D Loss: 0.0001, G Loss: 9.0922
# Epoch 19/50, Batch 0, D Loss: 0.0000, G Loss: 9.8079
# Epoch 19/50, Batch 100, D Loss: 0.0000, G Loss: 10.0719
# Epoch 19/50, Batch 200, D Loss: 0.0000, G Loss: 10.3018
# Epoch 19/50, Batch 300, D Loss: 0.0000, G Loss: 10.4501
# Epoch 19/50, Batch 400, D Loss: 0.0000, G Loss: 10.6694
# Epoch 20/50, Batch 0, D Loss: 0.0000, G Loss: 10.8942
# Epoch 20/50, Batch 100, D Loss: 0.0000, G Loss: 11.3157
# Epoch 20/50, Batch 200, D Loss: 0.0000, G Loss: 10.8009
# Epoch 20/50, Batch 300, D Loss: 0.0000, G Loss: 11.1189
# Epoch 20/50, Batch 400, D Loss: 0.0000, G Loss: 11.3475
# Epoch 21/50, Batch 0, D Loss: 0.0000, G Loss: 11.4807
# Epoch 21/50, Batch 100, D Loss: 0.0000, G Loss: 11.4420
# Epoch 21/50, Batch 200, D Loss: 0.0000, G Loss: 11.4349
# Epoch 21/50, Batch 300, D Loss: 0.0000, G Loss: 11.2154
# Epoch 21/50, Batch 400, D Loss: 0.0000, G Loss: 11.1185
# Epoch 22/50, Batch 0, D Loss: 0.0000, G Loss: 11.0088
# Epoch 22/50, Batch 100, D Loss: 0.0001, G Loss: 9.2045
# Epoch 22/50, Batch 200, D Loss: 0.0018, G Loss: 6.5343
# Epoch 22/50, Batch 300, D Loss: 0.0003, G Loss: 8.0078
# Epoch 22/50, Batch 400, D Loss: 0.0002, G Loss: 8.7241
# Epoch 23/50, Batch 0, D Loss: 0.0001, G Loss: 9.7293
# Epoch 23/50, Batch 100, D Loss: 0.0000, G Loss: 10.5454
# Epoch 23/50, Batch 200, D Loss: 0.0000, G Loss: 9.6779
# Epoch 23/50, Batch 300, D Loss: 0.0000, G Loss: 10.5117
# Epoch 23/50, Batch 400, D Loss: 0.0000, G Loss: 10.8378
# Epoch 24/50, Batch 0, D Loss: 0.0000, G Loss: 11.2165
# Epoch 24/50, Batch 100, D Loss: 0.0000, G Loss: 11.4126
# Epoch 24/50, Batch 200, D Loss: 0.0000, G Loss: 11.4479
# Epoch 24/50, Batch 300, D Loss: 0.0000, G Loss: 10.8922
# Epoch 24/50, Batch 400, D Loss: 0.0310, G Loss: 4.4492
# Epoch 25/50, Batch 0, D Loss: 0.0086, G Loss: 5.1720
# Epoch 25/50, Batch 100, D Loss: 0.0004, G Loss: 7.9718
# Epoch 25/50, Batch 200, D Loss: 0.0001, G Loss: 8.7516
# Epoch 25/50, Batch 300, D Loss: 0.0002, G Loss: 9.0399
# Epoch 25/50, Batch 400, D Loss: 0.0001, G Loss: 9.3778
# Epoch 26/50, Batch 0, D Loss: 0.0001, G Loss: 9.7698
# Epoch 26/50, Batch 100, D Loss: 0.0000, G Loss: 9.9999
# Epoch 26/50, Batch 200, D Loss: 0.0000, G Loss: 10.4701
# Epoch 26/50, Batch 300, D Loss: 0.0000, G Loss: 10.7357
# Epoch 26/50, Batch 400, D Loss: 0.0000, G Loss: 10.6961
# Epoch 27/50, Batch 0, D Loss: 0.0000, G Loss: 11.0497
# Epoch 27/50, Batch 100, D Loss: 0.0000, G Loss: 10.8636
# Epoch 27/50, Batch 200, D Loss: 0.0000, G Loss: 11.2429
# Epoch 27/50, Batch 300, D Loss: 0.0000, G Loss: 11.5051
# Epoch 27/50, Batch 400, D Loss: 0.0000, G Loss: 11.4705
# Epoch 28/50, Batch 0, D Loss: 0.0000, G Loss: 11.3782
# Epoch 28/50, Batch 100, D Loss: 0.0000, G Loss: 11.6314
# Epoch 28/50, Batch 200, D Loss: 0.0000, G Loss: 11.6495
# Epoch 28/50, Batch 300, D Loss: 0.0000, G Loss: 11.7364
# Epoch 28/50, Batch 400, D Loss: 0.0000, G Loss: 11.8930
# Epoch 29/50, Batch 0, D Loss: 0.0000, G Loss: 11.9679
# Epoch 29/50, Batch 100, D Loss: 0.0000, G Loss: 12.2040
# Epoch 29/50, Batch 200, D Loss: 0.0000, G Loss: 12.1047
# Epoch 29/50, Batch 300, D Loss: 0.0000, G Loss: 12.0631
# Epoch 29/50, Batch 400, D Loss: 0.0000, G Loss: 12.3593
# Epoch 30/50, Batch 0, D Loss: 0.0000, G Loss: 12.3285
# Epoch 30/50, Batch 100, D Loss: 0.0000, G Loss: 12.4780
# Epoch 30/50, Batch 200, D Loss: 0.0000, G Loss: 12.0342
# Epoch 30/50, Batch 300, D Loss: 0.0000, G Loss: 12.2398
# Epoch 30/50, Batch 400, D Loss: 0.0000, G Loss: 12.4292
# Epoch 31/50, Batch 0, D Loss: 0.0000, G Loss: 11.3859
# Epoch 31/50, Batch 100, D Loss: 0.2338, G Loss: 0.0000
# Epoch 31/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 31/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 31/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 32/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 32/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 32/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 32/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 32/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 33/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 33/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 33/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 33/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 33/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 34/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 34/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 34/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 34/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 34/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 35/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 35/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 35/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 35/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 35/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 36/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 36/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 36/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 36/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 36/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 37/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 37/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 37/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 37/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 37/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 38/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 38/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 38/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 38/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 38/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 39/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 39/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 39/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 39/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 39/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 40/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 40/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 40/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 40/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 40/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 41/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 41/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 41/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 41/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 41/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 42/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 42/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 42/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 42/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 42/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 43/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 43/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 43/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 43/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 43/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 44/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 44/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 44/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 44/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 44/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 45/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 45/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 45/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 45/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 45/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 46/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 46/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 46/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 46/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 46/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 47/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 47/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 47/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 47/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 47/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 48/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 48/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 48/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 48/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000
# Epoch 48/50, Batch 400, D Loss: 50.0000, G Loss: 0.0000
# Epoch 49/50, Batch 0, D Loss: 50.0000, G Loss: 0.0000
# Epoch 49/50, Batch 100, D Loss: 50.0000, G Loss: 0.0000
# Epoch 49/50, Batch 200, D Loss: 50.0000, G Loss: 0.0000
# Epoch 49/50, Batch 300, D Loss: 50.0000, G Loss: 0.0000

# %% [markdown]
#  Streamlit Web Application

# %%
import streamlit as st
import torch
import torch.nn as nn
import numpy as np
from PIL import Image
import io

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the same Generator class as in training
class Generator(nn.Module):
    def __init__(self, latent_dim=100, num_classes=10):
        super(Generator, self).__init__()
        self.latent_dim = latent_dim
        self.num_classes = num_classes

        self.label_embedding = nn.Embedding(num_classes, num_classes)

        self.model = nn.Sequential(
            nn.Linear(latent_dim + num_classes, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, 28*28),
            nn.Tanh()
        )

    def forward(self, noise, labels):
        label_embedding = self.label_embedding(labels)
        input_tensor = torch.cat([noise, label_embedding], dim=1)
        img = self.model(input_tensor)
        img = img.view(img.size(0), 1, 28, 28)
        return img

# Load the trained model
@st.cache_resource
def load_model():
    generator = Generator().to(device)
    generator.load_state_dict(torch.load('generator.pth', map_location=device))
    generator.eval()
    return generator

def generate_images(generator, digit, num_images=5):
    with torch.no_grad():
        # Create random noise
        noise = torch.randn(num_images, 100).to(device)
        # Create labels for the selected digit
        labels = torch.full((num_images,), digit).to(device)
        # Generate images
        fake_images = generator(noise, labels)
        # Convert to numpy and denormalize
        fake_images = fake_images.cpu().numpy()
        fake_images = (fake_images + 1) / 2  # Denormalize from [-1, 1] to [0, 1]
        return fake_images

def array_to_pil(img_array):
    # Convert numpy array to PIL Image
    img_array = (img_array * 255).astype(np.uint8)
    img = Image.fromarray(img_array.squeeze(), mode='L')
    return img

# Streamlit UI
st.title("Handwritten Digit Generator")
st.write("Generate handwritten digits using a trained GAN model")

# Load model
try:
    generator = load_model()
    st.success("Model loaded successfully!")
except:
    st.error("Could not load the model. Please ensure 'generator.pth' is available.")
    st.stop()

# Digit selection
selected_digit = st.selectbox("Select a digit to generate:", list(range(10)))

# Generate button
if st.button("Generate 5 Images"):
    with st.spinner("Generating images..."):
        # Generate images
        generated_images = generate_images(generator, selected_digit, 5)

        # Display images in a row
        cols = st.columns(5)
        for i, col in enumerate(cols):
            with col:
                pil_img = array_to_pil(generated_images[i])
                st.image(pil_img, caption=f"Generated {selected_digit}", width=100)

# Instructions
st.markdown("---")
st.markdown("### Instructions:")
st.markdown("1. Select a digit (0-9) from the dropdown")
st.markdown("2. Click 'Generate 5 Images' to create new handwritten digits")
st.markdown("3. The app will display 5 different variations of the selected digit")
# Out:
# 2025-06-22 17:12:30.645 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.753
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-06-22 17:12:30.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.802 Session state does not function when running a script without `streamlit run`
# 2025-06-22 17:12:30.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 17:12:30.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
